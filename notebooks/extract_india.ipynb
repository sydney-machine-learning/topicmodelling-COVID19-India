# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#keep only the tweet IDs before hydrating the tweets

rawli = ['corona_tweets_324.csv']
#'corona_tweets_107.csv', 'corona_tweets_114.csv', 'corona_tweets_268.csv', 'corona_tweets_128.csv', 'corona_tweets_135.csv', 'corona_tweets_142.csv', 'corona_tweets_149.csv', 'corona_tweets_156.csv', 'corona_tweets_163.csv', 'corona_tweets_170.csv', 'corona_tweets_177.csv', 'corona_tweets_184.csv', 'corona_tweets_191.csv', 'corona_tweets_198.csv', 'corona_tweets_205.csv', 'corona_tweets_212.csv', 'corona_tweets_219.csv', 'corona_tweets_226.csv', 'corona_tweets_233.csv', 'corona_tweets_240.csv', 'corona_tweets_247.csv', 'corona_tweets_254.csv', 'corona_tweets_261.csv', 'corona_tweets_268.csv', 'corona_tweets_275.csv', 'corona_tweets_282.csv', 'corona_tweets_289.csv', 'corona_tweets_296.csv', 'corona_tweets_303.csv', 'corona_tweets_310.csv', 'corona_tweets_317.csv'] #list of csv file titles
df_list = [] #list of dfs for raw csvs from the IEEE source
df_master = pd.DataFrame() #empty master dataframe
for raw in rawli:
    df_raw = pd.read_csv(r'/home/server4users/Desktop/Janhavi_covid-19 tweets/2020_september1_september2.csv'+raw, names=['id','sentiment_score'])
    df_master = pd.concat([df_master,df_raw], axis=0)

df_ID = df_master['id']
df_ID.to_csv(r'/home/server4users/Desktop/Cathy Vaccine Sentiment/ID only 324.csv', index=False, header=None)
#df_master.to_csv(r'/Users/cathy/Desktop/master 30-100.csv', index=False, header=None)
print(df_ID.shape)


# #concatenate the hydrated files into a master_hydrated file
# hydrateli = ['hydrate March.csv', 'hydrate April.csv','hydrate May.csv','hydrate June.csv','hydrate July.csv','hydrate August.csv','hydrate September.csv','hydrate October.csv','hydrate November.csv','hydrate December.csv','hydrate January.csv']
# df_master_hydrated = pd.DataFrame()
# for hydrated in hydrateli:
#     df_hydrate = pd.read_csv(r'/Users/cathy/Desktop/'+hydrated, low_memory=False, header = 0)
#     df_master_hydrated = pd.concat([df_master_hydrated, df_hydrate], axis=0)
# #df_master_hydrated.to_csv(r'/Users/cathy/Desktop/master hydrated Mar to Jan.csv', index=False, header=None)
#
#
# df_merge = df_master_hydrated.merge(df_master, on='id', how='left')
# print (df_merge.shape)
#
# count = df_merge['text'].str.contains("vaccine").sum()
# print(count)
#
# vaccine_df = df_merge[df_merge['text'].str.contains("vaccine")]
# vaccine_df[['Longitude','Latitude']] = vaccine_df['coordinates'].str.split(',',expand=True)
# vaccine_df.to_csv(r'/Users/cathy/Desktop/vaccine dataset.csv', index=False, header = 0)
# #print(list(vaccine_df['text']))

# %%
import shutil
csv_files = ['/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_210.csv', '/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_653.csv','/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_656.csv','/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_658.csv','/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_660.csv','/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_663.csv','/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_665.csv','/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_670.csv','/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_672.csv','/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_674.csv','/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_677.csv','/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_679.csv','/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_681.csv','/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_684.csv','/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_686.csv','/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_688.csv','/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_691.csv','/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_693.csv','/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_695.csv','/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_698.csv','/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_700.csv','/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_702.csv','/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_705.csv','/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_709.csv','/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/621-712/ready_corona_tweets_712.csv']
target_file_name = '621-712.csv';
shutil.copy(csv_files[0], target_file_name)
with open(target_file_name, 'a') as out_file:
    for source_file in csv_files[1:]:
        with open(source_file, 'r') as in_file:
#             if your csv doesn't contains header, then remove the following line.
            in_file.readline()
            shutil.copyfileobj(in_file, out_file)
            in_file.close()
    out_file.close()

# %% [markdown]
# Extracting India

# %%
import pandas as pd
df=pd.read_csv("/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/201-319/ready_corona_tweets_278.csv",engine='python', error_bad_lines=False)
df.head(12)
# Out:
# /tmp/ipykernel_919867/1062425938.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df=pd.read_csv("/media/trans-ai/hdd/Data-Twitter2022/tweet csvs/201-319/ready_corona_tweets_278.csv",engine='python', error_bad_lines=False)
#    coordinates                      created_at          hashtags  \
# 0          NaN  Mon Dec 21 04:25:44 +0000 2020               NaN
# 1          NaN  Mon Dec 21 04:25:46 +0000 2020               NaN
# 2          NaN  Mon Dec 21 04:25:45 +0000 2020               NaN
# 3          NaN  Mon Dec 21 04:25:44 +0000 2020               NaN
# 4          NaN  Mon Dec 21 04:25:45 +0000 2020               NaN
# 5          NaN  Mon Dec 21 04:25:44 +0000 2020  Covid_19 vaccine
# 6          NaN  Mon Dec 21 04:25:45 +0000 2020               NaN
# 7          NaN  Mon Dec 21 04:25:44 +0000 2020               NaN
# 8          NaN  Mon Dec 21 04:25:45 +0000 2020               NaN
# ...

# %%
df
# Out:
#         coordinates                      created_at hashtags  \
# 0               NaN  Mon Dec 21 04:25:44 +0000 2020      NaN
# 1               NaN  Mon Dec 21 04:25:46 +0000 2020      NaN
# 2               NaN  Mon Dec 21 04:25:45 +0000 2020      NaN
# 3               NaN  Mon Dec 21 04:25:44 +0000 2020      NaN
# 4               NaN  Mon Dec 21 04:25:45 +0000 2020      NaN
# ...             ...                             ...      ...
# 2608445         NaN  Tue Dec 22 04:25:13 +0000 2020      NaN
# 2608446         NaN  Tue Dec 22 04:25:14 +0000 2020      NaN
# 2608447         NaN  Tue Dec 22 04:25:14 +0000 2020     VETO
# 2608448         NaN  Tue Dec 22 04:25:14 +0000 2020      NaN
# 2608449         NaN  Tue Dec 22 04:25:14 +0000 2020      NaN
#
#                                                      media  \
# 0                                                      NaN
# 1                                                      NaN
# ...

# %%
df1 = df[['created_at','text','user_location']]
df1
# Out:
#                              created_at  \
# 0        Mon Dec 21 04:25:44 +0000 2020
# 1        Mon Dec 21 04:25:46 +0000 2020
# 2        Mon Dec 21 04:25:45 +0000 2020
# 3        Mon Dec 21 04:25:44 +0000 2020
# 4        Mon Dec 21 04:25:45 +0000 2020
# ...                                 ...
# 2608445  Tue Dec 22 04:25:13 +0000 2020
# 2608446  Tue Dec 22 04:25:14 +0000 2020
# 2608447  Tue Dec 22 04:25:14 +0000 2020
# 2608448  Tue Dec 22 04:25:14 +0000 2020
# 2608449  Tue Dec 22 04:25:14 +0000 2020
#
#                                                       text  \
# 0        Cure to covid is to snort 3 lines of this http...
# 1        Rich people did not experience the same pandem...
# 2        @elizabethnWA48 Maybe we could tie it into vac...
# 3        @BIHRLE I don't blame the workers. Other than ...
# 4        It’s just you and these dudes not taking the v...
# ...                                                    ...
# 2608445  Canada has been giving all small companies fun...
# ...

# %%
df_raw = df['user_location'].value_counts()

# %%
df_raw
# Out:
# United States                    40058
# USA                              16864
# London, England                  16050
# California, USA                  16003
# London                           13601
#                                  ...
# i am left this hellsite              1
# 울산                                   1
# London & Northampton, England        1
# She/Her (21+)                        1
# Victoria/Vancouver BC, Canada        1
# Name: user_location, Length: 270118, dtype: int64

# %%
print(df['user_location'].value_counts())
# Out:
# United States                    40058
# USA                              16864
# London, England                  16050
# California, USA                  16003
# London                           13601
#                                  ...
# i am left this hellsite              1
# 울산                                   1
# London & Northampton, England        1
# She/Her (21+)                        1
# Victoria/Vancouver BC, Canada        1
# Name: user_location, Length: 270118, dtype: int64

# %%
df1 = df1[df1['user_location'].str.contains('India|Kashmir|Maharashtra|Telangana|Delhi|Assam|Bihar|Bombay|Andhra Pradesh|Arunachal Pradesh|Assam|Bihar|Chhattisgarh|Goa|Gujarat|Haryana|Himachal Pradesh|Jammu and Kashmir|Jharkhand|Karnataka|Kerala|Madhya Pradesh|Maharashtra|Manipur|Meghalaya|Mizoram|Nagaland|Punjab|Rajasthan|Sikkim|Tamil Nadu|Telangana|Tripura|Uttarakhand|Uttar Pradesh|West Bengal|Andaman and Nicobar Islands|Mumbai|Lucknow|Sikkim|New Delhi|Kolkata|Patna|Goa|Banglore|Bangluru|Bhopal|Gandhi Nagar|Lucknow|Dispur|Chandigarh|Dadra and Nagar Haveli|Daman and Diu|Delhi|Lakshadweep|Puducherry|Pondicherry|Pune|Hyderabad')==True]

# %%
df1
# Out:
#                              created_at  \
# 105      Mon Dec 21 04:25:48 +0000 2020
# 111      Mon Dec 21 04:25:46 +0000 2020
# 158      Mon Dec 21 04:25:49 +0000 2020
# 159      Mon Dec 21 04:25:49 +0000 2020
# 177      Mon Dec 21 04:25:48 +0000 2020
# ...                                 ...
# 2608059  Tue Dec 22 04:25:02 +0000 2020
# 2608093  Tue Dec 22 04:25:03 +0000 2020
# 2608146  Tue Dec 22 04:25:06 +0000 2020
# 2608292  Tue Dec 22 04:25:09 +0000 2020
# 2608372  Tue Dec 22 04:25:12 +0000 2020
#
#                                                       text  \
# 105      Most major economies in Europe as also Canada,...
# 111      U.K. Imposes Fresh Lockdowns As It Struggle To...
# 158      A new strain of Covid-19 has created havoc in ...
# 159      The #BuckinghamPalace announced December 1 tha...
# 177      This day, 16 years ago, the Dr. Manmohan Singh...
# ...                                                    ...
# 2608059  the first place I’m going after COVID... check...
# ...

# %%
df1 = df1[df1['user_location'].str.contains("Indiana")==False]

# %%
df1
# Out:
#                              created_at  \
# 105      Mon Dec 21 04:25:48 +0000 2020
# 111      Mon Dec 21 04:25:46 +0000 2020
# 158      Mon Dec 21 04:25:49 +0000 2020
# 159      Mon Dec 21 04:25:49 +0000 2020
# 177      Mon Dec 21 04:25:48 +0000 2020
# ...                                 ...
# 2608058  Tue Dec 22 04:25:01 +0000 2020
# 2608093  Tue Dec 22 04:25:03 +0000 2020
# 2608146  Tue Dec 22 04:25:06 +0000 2020
# 2608292  Tue Dec 22 04:25:09 +0000 2020
# 2608372  Tue Dec 22 04:25:12 +0000 2020
#
#                                                       text  \
# 105      Most major economies in Europe as also Canada,...
# 111      U.K. Imposes Fresh Lockdowns As It Struggle To...
# 158      A new strain of Covid-19 has created havoc in ...
# 159      The #BuckinghamPalace announced December 1 tha...
# 177      This day, 16 years ago, the Dr. Manmohan Singh...
# ...                                                    ...
# 2608058  Because of the misguided policy, there is too ...
# ...

# %%
df1.to_csv("278_India.csv")
